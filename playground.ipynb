# %%
from src.opsrag.ingestion.models import Document

# %%
document = Document(
    id="1",
    content="",
    source="",
    file_name="",
    file_type="",
    domain="",
    document_type="",
    environment="",
    service="",
    status="",
    checksum=""
)
